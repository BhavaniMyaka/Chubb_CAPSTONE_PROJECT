td><td>1.448774832E9</td><td>null</td><td>685.73</td><td>Baseline</td></tr><tr><td>Indonesia</td><td>Asia</td><td>2014</td><td>Agriculture</td><td>6.59332315E8</td><td>null</td><td>1125.46</td><td>Renewable_Transition</td></tr><tr><td>India</td><td>Asia</td><td>2019</td><td>Residential</td><td>2.189388839E9</td><td>5108024.669896812</td><td>2995.14</td><td>Policy_Reduction</td></tr><tr><td>Germany</td><td>Europe</td><td>2003</td><td>Residential</td><td>2.57833453E8</td><td>3280172.947755079</td><td>1285.62</td><td>High_Growth</td></tr><tr><td>Pakistan</td><td>Asia</td><td>2000</td><td>Residential</td><td>1.472087447E9</td><td>null</td><td>445.34</td><td>Baseline</td></tr><tr><td>South Korea</td><td>Asia</td><td>2012</td><td>Industry</td><td>1.295814578E9</td><td>2989770.18498898</td><td>1946.81</td><td>Renewable_Transition</td></tr><tr><td>ARGENTINA</td><td>South America</td><td>2017</td><td>Industry</td><td>7.15942099E8</td><td>6503764.604537992</td><td>null</td><td>Policy_Reduction</td></tr><tr><td>Malaysia</td><td>Asia</td><td>1999</td><td>Energy</td><td>1.483048087E9</td><td>2132052.742583898</td><td>3473.28</td><td>Renewable_Transition</td></tr><tr><td>France</td><td>Europe</td><td>2000</td><td>Residential</td><td>1.321006104E9</td><td>805942.996587869</td><td>753.85</td><td>Renewable_Transition</td></tr><tr><td>Brazil</td><td>South Ame ...

# %% [markdown]
# #Basic Row Count Check

# %%
total_records = bronze_df.count()
print(f"Total records in Bronze table: {total_records}")
# Out:
# Total records in Bronze table: 18000

# %% [markdown]
# #Inspect Schema

# %%
bronze_df.printSchema()
# Out:
# root
#  |-- country: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- year: long (nullable = true)
#  |-- sector: string (nullable = true)
#  |-- population: double (nullable = true)
#  |-- gdp_billion_usd: double (nullable = true)
#  |-- co2_emissions_million_tons: double (nullable = true)
#  |-- scenario: string (nullable = true)

# %% [markdown]
# #Validate Time-Series Range (Year Column)

# %%
bronze_df.selectExpr(
    "min(year) as min_year",
    "max(year) as max_year"
).show()
# Out:
# +--------+--------+
# |min_year|max_year|
# +--------+--------+
# |    1995|    2024|
# +--------+--------+

# %% [markdown]
# #Validate Numeric Columns

# %%
from pyspark.sql.functions import col

numeric_columns = [
    "population",
    "gdp_billion_usd",
    "co2_emissions_million_tons"
]

for col_name in numeric_columns:
    invalid_count = bronze_df.filter(col(col_name) < 0).count()
    print(f"{col_name} - negative values count: {invalid_count}")
# Out:
# population - negative values count: 0
# gdp_billion_usd - negative values count: 0
# co2_emissions_million_tons - negative values count: 0

# %% [markdown]
# #Null Count Analysis

# %%
from pyspark.sql.functions import count, when, col

null_counts = [
    count(
        when(col(c).isNull(), c)
    ).alias(c)
    for c in bronze_df.columns
]

display(
    bronze_df.select(null_counts)
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th><th>region</th><th>year</th><th>sector</th><th>population</th><th>gdp_billion_usd</th><th>co2_emissions_million_tons</th><th>scenario</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td><td>2060</td><td>2048</td><td>2056</td><td>0</td></tr></tbody></table></div>
