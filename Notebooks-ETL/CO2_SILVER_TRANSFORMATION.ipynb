# %% [markdown]
# #Silver Layer For Transformations

# %% [markdown]
# #Imports

# %%
from pyspark.sql import functions as F
from pyspark.sql import Window

# %% [markdown]
# #Read Bronze Table

# %%
try:
    bronze_df = spark.table("co2_bronze.co_2_emissions_raw")
except Exception as e:
    print("Error reading Bronze table:", e)
    raise

# %% [markdown]
# #Remove Duplicate Records

# %%
silver_df = bronze_df.dropDuplicates([
    "country",
    "region",
    "year",
    "sector",
    "scenario"
])

# %% [markdown]
# #Standardize Country Names (Inconsistent Records)

# %%
silver_df = silver_df.withColumn(
    "country",
    F.initcap(F.lower(F.col("country")))
)

# %% [markdown]
# #Standardize Year Format

# %%
silver_df = silver_df.withColumn(
    "year",
    F.col("year").cast("int")
)
silver_df.show(5)
# Out:
# +-----------+------------+-------------+----+-------------+------------------+--------------------------+--------------------+
# |     sector|     country|       region|year|   population|   gdp_billion_usd|co2_emissions_million_tons|            scenario|
# +-----------+------------+-------------+----+-------------+------------------+--------------------------+--------------------+
# |Residential|       China|         Asia|2008|  2.1200037E8| 2632937.509436383|                    280.48|    Policy_Reduction|
# |Residential|      Mexico|North America|2015|  3.1981686E8| 362463.3469927282|                    265.47|Renewable_Transition|
# |  Transport|South Africa|       Africa|2017| 5.23530291E8|        1017442.99|                    455.71|            Baseline|
# |  Transport|    Pakistan|         Asia|2014|1.502512241E9|3924846.9457435603|                    954.99|         High_Growth|
# |  Transport| South Korea|         Asia|2001|1.242222012E9| 1957102.691733397|                    711.07|    Policy_Reduction|
# +-----------+------------+-------------+----+-------------+------------------+--------------------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# #Handle Missing Values

# %%
# Compute country-level averages
country_avg_df = (
    silver_df
    .groupBy("country")
    .agg(
        F.avg("population").alias("avg_population"),
        F.avg("gdp_billion_usd").alias("avg_gdp")
    )
)

# %%
# Join back and fill missing values
silver_df = silver_df.join(country_avg_df, on="country", how="left")

silver_df = silver_df.withColumn(
    "population",
    F.when(F.col("population").isNull(), F.col("avg_population"))
     .otherwise(F.col("population"))
)

silver_df = silver_df.withColumn(
    "gdp_billion_usd",
    F.when(F.col("gdp_billion_usd").isNull(), F.col("avg_gdp"))
     .otherwise(F.col("gdp_billion_usd"))
)

# Drop helper columns
silver_df = silver_df.drop("avg_population", "avg_gdp")

# %%
# Sector-wise average emissions
sector_avg_df = (
    silver_df
    .groupBy("sector")
    .agg(
        F.avg("co2_emissions_million_tons").alias("avg_co2")
    )
)

# %%
# Join & fill
silver_df = silver_df.join(sector_avg_df, on="sector", how="left")

silver_df = silver_df.withColumn(
    "co2_emissions_million_tons",
    F.when(
        F.col("co2_emissions_million_tons").isNull(),
        F.col("avg_co2")
    ).otherwise(F.col("co2_emissions_million_tons"))
)
# Drop helper columns
silver_df = silver_df.drop("avg_co2")

# %%
from pyspark.sql.functions import count, when, col

null_counts = [
    count(
        when(col(c).isNull(), c)
    ).alias(c)
    for c in silver_df.columns
]

display(
    silver_df.select(null_counts)
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sector</th><th>country</th><th>region</th><th>year</th><th>population</th><th>gdp_billion_usd</th><th>co2_emissions_million_tons</th><th>scenario</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# #Create Derived Metric: Emissions Per Capita

# %%
silver_df = silver_df.withColumn(
    "co2_per_capita",
    F.col("co2_emissions_million_tons") * 1_000_000 / F.col("population")
)

# %% [markdown]
# #Validate Scenario Values (Filter Inconsistent Records)

# %%
valid_scenarios = [
    "Baseline",
    "High_Growth",
    "Policy_Reduction",
    "Renewable_Transition"
]

silver_df = silver_df.filter(F.col("scenario").isin(valid_scenarios))

# %%
# Validate row count after transformations
total_records = silver_df.count()
print(f"Total records in Bronze table: {total_records}")
# Out:
# Total records in Bronze table: 18000

# %% [markdown]
# #Create co2_silver table schema

# %%
# %python
spark.sql("CREATE SCHEMA IF NOT EXISTS co2_silver")

(
    silver_df.write
    .format("delta")
    .option("mergeSchema", "true")
    .mode("overwrite")
    .saveAsTable("co2_silver.co2_emissions_clean")
)

# %% [markdown]
# #Write Silver Layer as Delta

# %%
try:
    (
        silver_df.write
        .format("delta")
        .mode("overwrite")
        .saveAsTable("co2_silver.co2_emissions_clean")
    )
except Exception as e:
    print("Error writing Silver table:", e)
    raise

# %%
spark.table("co2_silver.co2_emissions_clean").count()
# Out:
# 18000

# %%
display(
    spark.table("co2_silver.co2_emissions_clean").limit(10)
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sector</th><th>country</th><th>region</th><th>year</th><th>population</th><th>gdp_billion_usd</th><th>co2_emissions_million_tons</th><th>scenario</th><th>co2_per_capita</th></tr></thead><tbody><tr><td>Residential</td><td>China</td><td>Asia</td><td>2008</td><td>2.1200037E8</td><td>2632937.509436383</td><td>280.48</td><td>Policy_Reduction</td><td>1.3230165588861944</td></tr><tr><td>Residential</td><td>Mexico</td><td>North America</td><td>2015</td><td>3.1981686E8</td><td>362463.3469927282</td><td>265.47</td><td>Renewable_Transition</td><td>0.8300688087551108</td></tr><tr><td>Transport</td><td>South Africa</td><td>Africa</td><td>2017</td><td>5.23530291E8</td><td>1017442.99</td><td>455.71</td><td>Baseline</td><td>0.8704558414939929</td></tr><tr><td>Transport</td><td>Pakistan</td><td>Asia</td><td>2014</td><td>1.502512241E9</td><td>3924846.9457435603</td><td>954.99</td><td>High_Growth</td><td>0.6355954873049184</td></tr><tr><td>Transport</td><td>South Korea</td><td>Asia</td><td>2001</td><td>1.242222012E9</td><td>1957102.691733397</td><td>711.07</td><td>Policy_Reduction</td><td>0.5724178070674858</td></tr><tr><td>Agriculture</td><td>Argentina</td><td>South America</td><td>2018</td><td>7.25658382E8</td><td>8145921.734477208</td><td>222.24</td><td>Policy_Reduction</td><td>0.3062598124857049</td></tr><tr><td>Industry</td><td>Argentina</td><td>South America</td><td>1998</td><td>5.83910474E8</td><td>2771757.2689869353</td><td>1521.97</td><td>High_Growth</td><td>2.606512586722327</td></tr><tr><td>Transport</td><td>Italy</td><td>Europe</td><td>2016</td><td>1.038347097E9</td><td>1681175.4330652843</td><td>2776.96</td><td>Policy_Reduction</td><td>2.674404356715797</td></tr><tr><td>Transport</td><td>Germany</td><td>Europe</td><td>2016</td><td>2.93872598E8</td><td>6936214.669392974</td><td>2056.55</td><td>Policy_Reduction</td><td>6.998100585070542</td></tr><tr><td>Transport</td><td>United Kingdom</td><td>Europe</td><td>2019</td><td>1.07644084E8</td><td>2329724.6556659252</td><td>2085.47</td><td>Policy_Reduction</td><td>19.37375397239666</td></tr></tbody></table></div>
